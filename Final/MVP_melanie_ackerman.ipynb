# %% [markdown]
# ## Reader Preferences and Book Recommendations
# By Melanie Ackerman

# %% [markdown]
# ### Opportunity and Desired Impact
# As a “Big Five” publishing company, Penguin Random House (PRH) has a massive catalog spanning many genres and beloved authors. As such, their books appeal to many groups of readers, many of which likely overlap with each other in certain genres and sub-genres. A deeper understanding of readers' preferences could aid publishers in decision-making regarding book content as well as inform a future book recommendation system for readers.

# %% [markdown]
# ### Solution Path
# Public data from the website and application goodreads.com contain ratings for 10,000 popular books, books marked 'to read' by users, book metadata (e.g. author, year, etc.), and Goodreads tags/shelves/genres. The data is publicly available at this link: https://github.com/zygmuntz/goodbooks-10k
#
# For this project I will use clustering algorithms to segment reader audiences. By defining groups of readers, this will aid decision-makers at PRH in content and marketing choices to appeal to as a wide an audience as possible while maintaining integrity to the author and genre. This data will also inform a personalized recommendation system that readers can use to find their next read within PRH’s book catalog.
#
# To start, I have produced some visualizations to better understand the basics of the data. The below chart shows the distribution of average ratings for the books in the dataset. The chart is followed by two tables showing first the top 10 books ranked by average rating and, second, the top 10 books ranked by the number of user ratings. The number of ratings reveals how many users read and ranked the book, presumably suggesting the level of popularity. While some form of Harry Potter books appear in both lists, the overall deviations between the tables show that the most popular books are not necessarily the most highly reviewed. This is likely because the more people read a book, the less likely there is to be consensus on it, leading to a more spread out distribution of reviews and possibly bringing down the average.

# %% [markdown]
# ![Ratings%20distribution.png](attachment:Ratings%20distribution.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
